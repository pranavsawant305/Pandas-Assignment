# %% [markdown]
# # Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset *chipotle.tsv*

# %%
df=pd.read_csv("C:\PRANAV\Madrid Software\Python\pandas assignment\sorting\chipotle.tsv",sep="/t")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2104\576175709.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df=pd.read_csv("C:\PRANAV\Madrid Software\Python\pandas assignment\sorting\chipotle.tsv",sep="/t")

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
df
# Out:
#      order_id\tquantity\titem_name\tchoice_description\titem_price
# 0       1\t1\tChips and Fresh Tomato Salsa\tNULL\t$2.39
# 1                       1\t1\tIzze\t[Clementine]\t$3.39
# 2                1\t1\tNantucket Nectar\t[Apple]\t$3.39
# 3     1\t1\tChips and Tomatillo-Green Chili Salsa\tN...
# 4     2\t2\tChicken Bowl\t[Tomatillo-Red Chili Salsa...
# ...                                                 ...
# 4617  1833\t1\tSteak Burrito\t[Fresh Tomato Salsa, [...
# 4618  1833\t1\tSteak Burrito\t[Fresh Tomato Salsa, [...
# 4619  1834\t1\tChicken Salad Bowl\t[Fresh Tomato Sal...
# 4620  1834\t1\tChicken Salad Bowl\t[Fresh Tomato Sal...
# 4621  1834\t1\tChicken Salad Bowl\t[Fresh Tomato Sal...
#
# [4622 rows x 1 columns]

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?
#
# Use `str` attribute to remove the $ sign and convert the column to proper numeric type data before filtering.

# %%
df=df["order_id\tquantity\titem_name\tchoice_description\titem_price"].str.split("\t",expand=True)
df.columns=["order_id","quantity","item_name","choice_description","item_price"]

# %%
df
# Out:
#      order_id quantity                              item_name  \
# 0           1        1           Chips and Fresh Tomato Salsa
# 1           1        1                                   Izze
# 2           1        1                       Nantucket Nectar
# 3           1        1  Chips and Tomatillo-Green Chili Salsa
# 4           2        2                           Chicken Bowl
# ...       ...      ...                                    ...
# 4617     1833        1                          Steak Burrito
# 4618     1833        1                          Steak Burrito
# 4619     1834        1                     Chicken Salad Bowl
# 4620     1834        1                     Chicken Salad Bowl
# 4621     1834        1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                  NULL      $2.39
# 1                                          [Clementine]      $3.39
# ...

# %%
df['item_price'] = df['item_price'].str.replace('$', '').astype(float)
df
# Out:
#      order_id quantity                              item_name  \
# 0           1        1           Chips and Fresh Tomato Salsa
# 1           1        1                                   Izze
# 2           1        1                       Nantucket Nectar
# 3           1        1  Chips and Tomatillo-Green Chili Salsa
# 4           2        2                           Chicken Bowl
# ...       ...      ...                                    ...
# 4617     1833        1                          Steak Burrito
# 4618     1833        1                          Steak Burrito
# 4619     1834        1                     Chicken Salad Bowl
# 4620     1834        1                     Chicken Salad Bowl
# 4621     1834        1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                  NULL        2.39
# 1                                          [Clementine]        3.39
# ...

# %%
df[df["item_price"]>10]
# Out:
#      order_id quantity           item_name  \
# 4           2        2        Chicken Bowl
# 5           3        1        Chicken Bowl
# 7           4        1       Steak Burrito
# 13          7        1        Chicken Bowl
# 23         12        1     Chicken Burrito
# ...       ...      ...                 ...
# 4610     1830        1       Steak Burrito
# 4611     1830        1      Veggie Burrito
# 4617     1833        1       Steak Burrito
# 4618     1833        1       Steak Burrito
# 4619     1834        1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %% [markdown]
# ### Step 5. What is the price of each item?
#
# print a data frame with only two columns `item_name` and `item_price`

# %%
df["item_name"].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
df['price_per_item'] = df['item_price'] / df['quantity']
unique_items = df[['item_name', 'price_per_item']].drop_duplicates().reset_index(drop=True)
unique_items.columns = ['item_name', 'item_price']

# %%
unique_items
# Out:
#                                  item_name  item_price
# 0             Chips and Fresh Tomato Salsa        2.39
# 1                                     Izze        3.39
# 2                         Nantucket Nectar        3.39
# 3    Chips and Tomatillo-Green Chili Salsa        2.39
# 4                             Chicken Bowl        8.49
# ..                                     ...         ...
# 134                          Chicken Salad        8.19
# 135                           Chicken Bowl        8.50
# 136                    Chips and Guacamole        4.25
# 137                                  Chips        1.99
# 138                          Barbacoa Bowl       11.49
#
# [139 rows x 2 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
unique_items_sorted = unique_items.sort_values(by='item_name').reset_index(drop=True)
unique_items_sorted
# Out:
#              item_name  item_price
# 0    6 Pack Soft Drink        6.49
# 1        Barbacoa Bowl       11.49
# 2        Barbacoa Bowl       11.48
# 3        Barbacoa Bowl        8.99
# 4        Barbacoa Bowl       11.75
# ..                 ...         ...
# 134  Veggie Salad Bowl       11.25
# 135  Veggie Salad Bowl        8.75
# 136  Veggie Soft Tacos        8.49
# 137  Veggie Soft Tacos       11.25
# 138  Veggie Soft Tacos        8.75
#
# [139 rows x 2 columns]

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
df[df["item_price"]==df["item_price"].max()]["quantity"].values
# Out:
# array(['15'], dtype=object)

# %% [markdown]
# ### Step 8. How many times were a Veggie Salad Bowl ordered?

# %%
df['quantity'] = df['quantity'].astype(float)

# %%
df[df["item_name"]=="Veggie Salad Bowl"]["quantity"].sum()
# Out:
# 18.0

# %% [markdown]
# ### Step 9. How many times people orderd more than one Canned Soda?

# %%
df
# Out:
#      order_id  quantity                              item_name  \
# 0           1       1.0           Chips and Fresh Tomato Salsa
# 1           1       1.0                                   Izze
# 2           1       1.0                       Nantucket Nectar
# 3           1       1.0  Chips and Tomatillo-Green Chili Salsa
# 4           2       2.0                           Chicken Bowl
# ...       ...       ...                                    ...
# 4617     1833       1.0                          Steak Burrito
# 4618     1833       1.0                          Steak Burrito
# 4619     1834       1.0                     Chicken Salad Bowl
# 4620     1834       1.0                     Chicken Salad Bowl
# 4621     1834       1.0                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                  NULL        2.39
# 1                                          [Clementine]        3.39
# ...

# %%
df[df["item_name"]=="Canned Soda"]
# Out:
#      order_id  quantity    item_name choice_description  item_price
# 18          9       2.0  Canned Soda           [Sprite]        2.18
# 28         14       1.0  Canned Soda       [Dr. Pepper]        1.09
# 51         23       2.0  Canned Soda     [Mountain Dew]        2.18
# 53         24       1.0  Canned Soda           [Sprite]        1.09
# 107        47       1.0  Canned Soda       [Dr. Pepper]        1.09
# ...       ...       ...          ...                ...         ...
# 3897     1562       1.0  Canned Soda     [Mountain Dew]        1.09
# 3926     1575       1.0  Canned Soda       [Dr. Pepper]        1.09
# 3936     1578       1.0  Canned Soda  [Diet Dr. Pepper]        1.09
# 4008     1604       1.0  Canned Soda        [Diet Coke]        1.09
# 4051     1621       1.0  Canned Soda           [Sprite]        1.09
#
# [104 rows x 5 columns]

# %%
canned_soda_orders = df[(df['item_name'] == 'Canned Soda') & (df['quantity'] > 1)]

# %%
canned_soda_orders
# Out:
#      order_id  quantity    item_name choice_description  item_price  \
# 18          9       2.0  Canned Soda           [Sprite]        2.18
# 51         23       2.0  Canned Soda     [Mountain Dew]        2.18
# 162        73       2.0  Canned Soda        [Diet Coke]        2.18
# 171        76       2.0  Canned Soda  [Diet Dr. Pepper]        2.18
# 350       150       2.0  Canned Soda        [Diet Coke]        2.18
# 352       151       2.0  Canned Soda        [Coca Cola]        2.18
# 698       287       2.0  Canned Soda        [Coca Cola]        2.18
# 700       288       2.0  Canned Soda        [Coca Cola]        2.18
# 909       376       2.0  Canned Soda     [Mountain Dew]        2.18
# 1091      450       2.0  Canned Soda       [Dr. Pepper]        2.18
# 1092      450       2.0  Canned Soda        [Coca Cola]        2.18
# 1944      787       2.0  Canned Soda       [Dr. Pepper]        2.18
# 2135      859       2.0  Canned Soda        [Diet Coke]        2.18
# ...
