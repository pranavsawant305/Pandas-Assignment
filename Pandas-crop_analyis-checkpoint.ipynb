# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("apy_2.csv")
df
# Out:
#        Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0               0       Karnataka         UDUPI       2005  Rabi
# 1               1  Madhya Pradesh       GWALIOR       2003  Whole Year
# 2               2  Andhra Pradesh      CHITTOOR       2010  Rabi
# 3               3  Andhra Pradesh       KRISHNA       2014  Rabi
# 4               4   Uttar Pradesh     SULTANPUR       2011  Rabi
# ...           ...             ...           ...        ...          ...
# 73822       73822   Uttar Pradesh     SULTANPUR       2001  Rabi
# 73823       73823    Chhattisgarh          DURG       2014  Rabi
# 73824       73824   Uttar Pradesh    RAE BARELI       2010  Summer
# 73825       73825           Assam        KAMRUP       1998  Rabi
# 73826       73826  Andhra Pradesh        GUNTUR       2005  Rabi
#
#                     Crop      Area  Production
# 0             Horse-gram    1122.0       836.0
# 1                Brinjal     194.0         0.0
# ...

# %% [markdown]
# ### checking shape

# %%
df.shape
# Out:
# (73827, 8)

# %% [markdown]
# ### delete column unmamed:0

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
df
# Out:
#            State_Name District_Name  Crop_Year       Season  \
# 0           Karnataka         UDUPI       2005  Rabi
# 1      Madhya Pradesh       GWALIOR       2003  Whole Year
# 2      Andhra Pradesh      CHITTOOR       2010  Rabi
# 3      Andhra Pradesh       KRISHNA       2014  Rabi
# 4       Uttar Pradesh     SULTANPUR       2011  Rabi
# ...               ...           ...        ...          ...
# 73822   Uttar Pradesh     SULTANPUR       2001  Rabi
# 73823    Chhattisgarh          DURG       2014  Rabi
# 73824   Uttar Pradesh    RAE BARELI       2010  Summer
# 73825           Assam        KAMRUP       1998  Rabi
# 73826  Andhra Pradesh        GUNTUR       2005  Rabi
#
#                     Crop      Area  Production
# 0             Horse-gram    1122.0       836.0
# 1                Brinjal     194.0         0.0
# 2                Sesamum     334.0       118.0
# 3                 Tomato     538.0      7289.0
# 4              Coriander      59.0        33.0
# ...

# %% [markdown]
# ### drop the rows with nan if any

# %%
df.dropna(axis=0,how="any",inplace=True)

# %%
df.shape
# Out:
# (72679, 7)

# %% [markdown]
# ### checking missing values in df

# %%
df.isnull().sum()
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %% [markdown]
# ### Which of these crops are produced during the Summer season?
#
#
# - Arecanut, Arhar/Tur, Bajra, Castor seed
# - Paddy, Maize, Moong (Green Gram), Onion, Sunflower
# - Banana, Coriander, Gram, Rapeseed & Mustard
# - Rice, Sugarcane, Paddy, Tomato

# %%
df.sample(5)
# Out:
#              State_Name  District_Name  Crop_Year       Season           Crop  \
# 39953         Karnataka        BELGAUM       2011  Summer           Sunflower
# 64461            Sikkim  EAST DISTRICT       2008  Kharif       Small millets
# 61272  Himachal Pradesh          SOLAN       2004  Rabi                 Wheat
# 32674           Haryana          SIRSA       2008  Kharif                Moth
# 55056         Karnataka         HASSAN       2014  Whole Year      Dry ginger
#
#           Area  Production
# 39953    490.0       518.0
# 64461   1430.0      1340.0
# 61272  24694.0     47483.0
# 32674    872.0       200.0
# 55056  15736.0    510979.0

# %%
df["Season"].unique()
# Out:
# array(['Rabi       ', 'Whole Year ', 'Kharif     ', 'Autumn     ',
#        'Winter     ', 'Summer     '], dtype=object)

# %%
df[df["Season"]=="Summer     "]["Crop"].unique()
# Out:
# array(['Groundnut', 'Maize', 'Rice', 'Sesamum', 'Wheat', 'Onion', 'Urad',
#        'Peas & beans (Pulses)', 'Sunflower', 'Ragi', 'Bajra',
#        'Moong(Green Gram)', 'Cotton(lint)', 'Jowar', 'Cowpea(Lobia)',
#        'Tobacco', 'Horse-gram', 'Dry chillies', 'Paddy', 'Turmeric',
#        'Arhar/Tur', 'Banana', 'Potato', 'Dry ginger', 'Brinjal',
#        'Sugarcane', 'Other  Rabi pulses', 'Small millets',
#        'Total foodgrain'], dtype=object)

# %% [markdown]
# - Arecanut, Arhar/Tur, Bajra, Castor seed
# - Paddy, Maize, Moong (Green Gram), Onion, Sunflower
# - Banana, Coriander, Gram, Rapeseed & Mustard
# - Rice, Sugarcane, Paddy, Tomato

# %%
df.groupby(["Season"])["Crop"].unique()
# Out:
# Season
# Autumn         [Rice, Groundnut, Maize, Moong(Green Gram), Ar...
# Kharif         [Niger seed, Groundnut, Peas & beans (Pulses),...
# Rabi           [Horse-gram, Sesamum, Tomato, Coriander, Black...
# Summer         [Groundnut, Maize, Rice, Sesamum, Wheat, Onion...
# Whole Year     [Brinjal, Onion, Potato, Turmeric, Sweet potat...
# Winter         [Horse-gram, Rice, Rapeseed &Mustard, Moong(Gr...
# Name: Crop, dtype: object

# %% [markdown]
# ### ANS : Paddy, Maize, Moong (Green Gram), Onion, Sunflower

# %% [markdown]
# ### During which year did Haryana have the highest crop production?
# - 2013
# - 2011
# - 1997
# - 2008

# %%
df.sample(2)
# Out:
#            State_Name District_Name  Crop_Year       Season  \
# 73766  Madhya Pradesh      SHAJAPUR       2000  Kharif
# 11294        Nagaland      TUENSANG       2003  Kharif
#
#                       Crop    Area  Production
# 73766  Other Kharif pulses  2857.0       763.0
# 11294            Arhar/Tur   810.0       780.0

# %%
df["State_Name"].unique()
# Out:
# array(['Karnataka', 'Madhya Pradesh', 'Andhra Pradesh', 'Uttar Pradesh',
#        'Rajasthan', 'Assam', 'Bihar', 'Odisha', 'Chhattisgarh', 'Kerala',
#        'Telangana ', 'Maharashtra', 'Nagaland', 'Puducherry', 'Gujarat',
#        'Himachal Pradesh', 'Tamil Nadu', 'West Bengal',
#        'Jammu and Kashmir ', 'Arunachal Pradesh', 'Uttarakhand',
#        'Haryana', 'Mizoram', 'Manipur', 'Punjab', 'Jharkhand',
#        'Meghalaya', 'Andaman and Nicobar Islands', 'Sikkim', 'Tripura',
#        'Dadra and Nagar Haveli', 'Goa', 'Chandigarh'], dtype=object)

# %%
df_h=df[df["State_Name"]=="Haryana"]
df_h
# Out:
#       State_Name District_Name  Crop_Year       Season                 Crop  \
# 77       Haryana         MEWAT       2006  Rabi                        Gram
# 114      Haryana          JIND       2008  Kharif              Cotton(lint)
# 132      Haryana  MAHENDRAGARH       2006  Kharif                     Bajra
# 162      Haryana       JHAJJAR       2002  Whole Year                Banana
# 185      Haryana       BHIWANI       1997  Kharif       Other Kharif pulses
# ...          ...           ...        ...          ...                  ...
# 73392    Haryana       GURGAON       1999  Whole Year                 Onion
# 73558    Haryana       PANIPAT       2008  Kharif                      Rice
# 73621    Haryana       JHAJJAR       2004  Rabi                       Wheat
# 73635    Haryana  MAHENDRAGARH       2006  Rabi                       Wheat
# 73772    Haryana       JHAJJAR       2006  Rabi           Rapeseed &Mustard
#
#            Area  Production
# ...

# %%
df_h.groupby(["Crop_Year"])["Production"].sum().sort_values(ascending=False)
# Out:
# Crop_Year
# 2008    9647100.0
# 2005    9328300.0
# 2011    9021300.0
# 2003    8437562.0
# 2012    7996416.0
# 2002    7837700.0
# 2004    7523400.0
# 2007    7323500.0
# 1999    7188901.0
# 2001    7009900.0
# 1998    6653600.0
# 2006    6566600.0
# 2000    5872800.0
# 2010    5548900.0
# 2009    5214480.0
# 1997    3376800.0
# Name: Production, dtype: float64

# %% [markdown]
# ## ans : 2008

# %% [markdown]
# ### The maximum and minimum area for production were in the years?
# 1997 and 2014
# 1998 and 2015
# 1997 and 2015
# 1999 and 2005

# %%
df.head(2)
# Out:
#        State_Name District_Name  Crop_Year       Season        Crop    Area  \
# 0       Karnataka         UDUPI       2005  Rabi         Horse-gram  1122.0
# 1  Madhya Pradesh       GWALIOR       2003  Whole Year      Brinjal   194.0
#
#    Production
# 0       836.0
# 1         0.0

# %%
df.groupby(["Crop_Year"])["Area"].sum().sort_values()
# Out:
# Crop_Year
# 2015     1313314.00
# 2014    34188857.84
# 2013    41895685.00
# 2001    43603438.77
# 2012    44369268.00
# 2007    44971304.38
# 2005    45296672.88
# 2011    45835655.41
# 2002    48328531.15
# 2003    48954140.97
# 1998    49317287.00
# 2008    49604477.00
# 2000    50530198.00
# 2009    50772638.00
# 2010    50813109.78
# 2006    51393712.02
# 1999    51841049.00
# 2004    53445367.24
# 1997    68245111.00
# Name: Area, dtype: float64

# %% [markdown]
# ### Which state in India had the second lowest crop production? (overall, for all years)
# - Meghalaya
# - Chandigarh
# - Mizoram
# - Manipur

# %%
df.groupby(["State_Name"])["Production"].sum().sort_values(ascending=True)
# Out:
# State_Name
# Chandigarh                     1.580450e+04
# Mizoram                        4.579428e+05
# Sikkim                         5.507250e+05
# Dadra and Nagar Haveli         6.247060e+05
# Manipur                        1.658617e+06
# Arunachal Pradesh              2.035912e+06
# Jharkhand                      3.319141e+06
# Meghalaya                      3.639914e+06
# Nagaland                       3.925012e+06
# Jammu and Kashmir              4.018134e+06
# Tripura                        4.278173e+06
# Himachal Pradesh               5.198802e+06
# Chhattisgarh                   3.132986e+07
# Uttarakhand                    4.017398e+07
# Odisha                         4.563306e+07
# Puducherry                     7.326832e+07
# Rajasthan                      8.671658e+07
# Haryana                        1.145473e+08
# Bihar                          1.151581e+08
# Telangana                      1.202722e+08
# Madhya Pradesh                 1.337226e+08
# ...

# %% [markdown]
# ### ans : mizoram

# %% [markdown]
# ### What were the top three produced crops in the year 2012?
# - Wheat, Potato, Rice
# - Coconut, Potato, Sugarcane
# - Coconut, Sugarcane, Rice
# - Rice, Sugarcane, Maize

# %%
df_12=df[df["Crop_Year"]==2012]
df_12
# Out:
#            State_Name     District_Name  Crop_Year       Season  \
# 26           Nagaland           KIPHIRE       2012  Rabi
# 44     Madhya Pradesh       HOSHANGABAD       2012  Whole Year
# 74       Chhattisgarh          DHAMTARI       2012  Kharif
# 76        Uttarakhand  UDAM SINGH NAGAR       2012  Rabi
# 94         Tamil Nadu       KRISHNAGIRI       2012  Kharif
# ...               ...               ...        ...          ...
# 73706          Kerala            KOLLAM       2012  Whole Year
# 73724   Uttar Pradesh             UNNAO       2012  Rabi
# 73769       Karnataka   BENGALURU URBAN       2012  Whole Year
# 73771       Meghalaya  SOUTH GARO HILLS       2012  Whole Year
# 73805  Andhra Pradesh           KRISHNA       2012  Rabi
#
#                     Crop    Area  Production
# 26     Rapeseed &Mustard  1190.0      1200.0
# 44             Coriander   305.0       143.0
# 74            Horse-gram   124.0        42.0
# 76                  Gram    28.0        17.0
# ...

# %%
df_12.groupby("Crop")["Production"].sum().sort_values(ascending=False)
# Out:
# Crop
# Coconut           1.208299e+09
# Sugarcane         1.143474e+08
# Rice              3.371318e+07
# Wheat             2.448045e+07
# Potato            1.006466e+07
#                       ...
# Pome Granet       8.720000e+02
# Blackgram         7.000000e+01
# Grapes            1.800000e+01
# Cardamom          1.200000e+01
# other oilseeds    1.000000e+00
# Name: Production, Length: 69, dtype: float64

# %% [markdown]
# ## ans : Coconut, Sugarcane, Rice

# %% [markdown]
# ### What is the standard deviation for Area of production?
# - 52957.44 (approx.)
# - 12167.42 (approx.)
# - 49177.60 (approx.)
# - 48848.27 (approx.)

# %%
df["Area"].std()
# Out:
# 49177.603127123424

# %% [markdown]
# ans : 49177.60 (approx.)

# %% [markdown]
# ### Which is the crop that gave the highest production to the state of Andhra Pradesh?
# - Sugarcane
# - Wheat
# - Banana
# - Coconut

# %%
df_a=df[df["State_Name"]=="Andhra Pradesh"]
df_a
# Out:
#            State_Name District_Name  Crop_Year       Season  \
# 2      Andhra Pradesh      CHITTOOR       2010  Rabi
# 3      Andhra Pradesh       KRISHNA       2014  Rabi
# 86     Andhra Pradesh       KURNOOL       2011  Kharif
# 126    Andhra Pradesh      CHITTOOR       2000  Whole Year
# 175    Andhra Pradesh      CHITTOOR       2007  Kharif
# ...               ...           ...        ...          ...
# 73681  Andhra Pradesh  SPSR NELLORE       2006  Whole Year
# 73713  Andhra Pradesh       KRISHNA       2005  Kharif
# 73787  Andhra Pradesh      PRAKASAM       2006  Rabi
# 73805  Andhra Pradesh       KRISHNA       2012  Rabi
# 73826  Andhra Pradesh        GUNTUR       2005  Rabi
#
#                     Crop      Area  Production
# 2                Sesamum     334.0       118.0
# 3                 Tomato     538.0      7289.0
# 86     Moong(Green Gram)    1284.0       824.0
# 126            Cashewnut     126.0        27.0
# 175           Horse-gram    4000.0      2000.0
# ...

# %%
df_a.groupby(["Crop"])["Production"].sum().sort_values(ascending=False)
# Out:
# Crop
# Coconut              2.979218e+09
# Sugarcane            7.585185e+07
# Rice                 4.599650e+07
# Groundnut            5.430417e+06
# Maize                4.853811e+06
#                          ...
# Cucumber             0.000000e+00
# Bottle Gourd         0.000000e+00
# Other Vegetables     0.000000e+00
# Peas  (vegetable)    0.000000e+00
# other fibres         0.000000e+00
# Name: Production, Length: 67, dtype: float64

# %% [markdown]
# ####  ans  Coconut

# %% [markdown]
# ### Which of the following statements is true? (Select all that applies)
# - The overall production during the Kharif season is 2,029,970,000 (approx.)
# - The overall production during the Summer season is 51,992,900 (approx.)
# - The overall production during the Autumn season is 14,413,770 (approx.)
# - The overall production during the Kharif season is 1,282,056,700 (approx.)

# %%
df.groupby(["Season"])["Production"].sum()
# Out:
# Season
# Autumn         1.889659e+07
# Kharif         1.282057e+09
# Rabi           5.928215e+08
# Summer         5.199288e+07
# Whole Year     3.009350e+10
# Winter         1.294610e+08
# Name: Production, dtype: float64

# %% [markdown]
# ### ans : 2nd and 4th opetion is True

# %% [markdown]
# ### Which state has the lowest area of production?
# - Puducherry
# - Chandigarh
# - Kerala
# - Goa

# %%
df.groupby(["State_Name"])["Area"].sum().sort_values()
# Out:
# State_Name
# Chandigarh                     2.791000e+03
# Andaman and Nicobar Islands    8.531894e+04
# Dadra and Nagar Haveli         1.182820e+05
# Puducherry                     1.206340e+05
# Goa                            2.702040e+05
# Mizoram                        2.711313e+05
# Sikkim                         3.922050e+05
# Manipur                        6.121800e+05
# Meghalaya                      1.270237e+06
# Arunachal Pradesh              1.283609e+06
# Tripura                        1.605874e+06
# Nagaland                       1.800631e+06
# Jammu and Kashmir              2.744164e+06
# Jharkhand                      2.748473e+06
# Himachal Pradesh               2.897344e+06
# Uttarakhand                    5.714422e+06
# Kerala                         8.871677e+06
# Assam                          2.065623e+07
# Telangana                      2.225371e+07
# Chhattisgarh                   2.547540e+07
# Haryana                        2.756965e+07
# ...

# %% [markdown]
# ### ans : Chandigarh

# %% [markdown]
# - What is the mean for the area of production?
# - 17065.81 (approx.)
# - 12035.39 (approx.)
# - 11868.49 (approx.)
# - 58250.34 (approx.)

# %%
df["Area"].mean()
# Out:
# 12035.385977242398

# %% [markdown]
# ans : 12035.39 (approx.)

# %% [markdown]
# ### What is the correlation coefficient between Area and Production?
# - 37.686
# - 0.37686
# - 3.7686
# - 0.037686

# %%
import seaborn as sns
sns.heatmap(df[["Area","Production"]].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ans : - 0.037686

# %% [markdown]
# ### Which is the only crop that has the highest production during autumn, summer, and winter?
#
# - Rice
# - Maize
# - Paddy
# - Jute

# %%
k=df.groupby(["Season","Crop"])["Production"].agg(["sum"]).reset_index()
k
# Out:
#           Season          Crop        sum
# 0    Autumn          Arhar/Tur     3937.0
# 1    Autumn             Banana     3980.0
# 2    Autumn       Dry chillies    10513.0
# 3    Autumn         Dry ginger      360.0
# 4    Autumn          Groundnut    97968.5
# ..           ...           ...        ...
# 312  Winter            Sesamum    32707.8
# 313  Winter          Sugarcane  4839051.3
# 314  Winter       Sweet potato       30.0
# 315  Winter               Urad    74790.7
# 316  Winter              Wheat     1652.0
#
# [317 rows x 3 columns]

# %%
k["Season"]
# Out:
# 0      Autumn
# 1      Autumn
# 2      Autumn
# 3      Autumn
# 4      Autumn
#           ...
# 312    Winter
# 313    Winter
# 314    Winter
# 315    Winter
# 316    Winter
# Name: Season, Length: 317, dtype: object

# %%
k["Season"].unique()
# Out:
# array(['Autumn     ', 'Kharif     ', 'Rabi       ', 'Summer     ',
#        'Whole Year ', 'Winter     '], dtype=object)

# %%
k[k["Season"]=="Autumn     "].sort_values(by="sum",ascending=False)
# Out:
#          Season                   Crop          sum
# 13  Autumn                        Rice  14820963.70
# 6   Autumn                       Maize   3089100.78
# 9   Autumn                       Paddy    521140.00
# 5   Autumn                        Jute    155210.90
# 12  Autumn                        Ragi    121504.38
# 4   Autumn                   Groundnut     97968.50
# 19  Autumn                        Urad     39608.00
# 7   Autumn           Moong(Green Gram)     24799.50
# 2   Autumn                Dry chillies     10513.00
# 14  Autumn                     Sesamum      5302.10
# 1   Autumn                      Banana      3980.00
# 0   Autumn                   Arhar/Tur      3937.00
# 16  Autumn                   Sugarcane      1291.20
# 15  Autumn               Small millets       595.00
# 3   Autumn                  Dry ginger       360.00
# 17  Autumn                     Tapioca       130.00
# 11  Autumn                      Potato       100.00
# ...

# %%
k[k["Season"]=="Winter     "].sort_values(by="sum",ascending=False)
# Out:
#           Season                   Crop           sum
# 310  Winter                        Rice  1.113293e+08
# 307  Winter                      Potato  8.277893e+06
# 313  Winter                   Sugarcane  4.839051e+06
# 305  Winter                       Paddy  4.622613e+06
# 300  Winter                  Horse-gram  8.732610e+04
# 308  Winter                        Ragi  8.064870e+04
# 315  Winter                        Urad  7.479070e+04
# 302  Winter           Moong(Green Gram)  6.656960e+04
# 312  Winter                     Sesamum  3.270780e+04
# 294  Winter                   Arhar/Tur  1.260100e+04
# 299  Winter                   Groundnut  1.229040e+04
# 309  Winter           Rapeseed &Mustard  9.776100e+03
# 295  Winter                      Banana  8.770000e+03
# 301  Winter                       Maize  3.129800e+03
# 316  Winter                       Wheat  1.652000e+03
# 296  Winter                Dry chillies  7.000000e+02
# ...

# %%
k[k["Season"]=="Summer     "].sort_values(by="sum",ascending=False)
# Out:
#           Season                   Crop         sum
# 183  Summer                        Rice  38709052.2
# 175  Summer                       Maize   4840564.0
# 172  Summer                   Groundnut   2083123.3
# 165  Summer                       Bajra   1779222.0
# 179  Summer                       Paddy   1638436.0
# 176  Summer           Moong(Green Gram)    735738.3
# 184  Summer                     Sesamum    618864.8
# 177  Summer                       Onion    596379.0
# 166  Summer                      Banana    272080.0
# 187  Summer                   Sunflower    170886.0
# 181  Summer                      Potato    168904.0
# 191  Summer                        Urad    107210.8
# 182  Summer                        Ragi    103252.8
# 174  Summer                       Jowar     59373.0
# 170  Summer                Dry chillies     54145.0
# 192  Summer                       Wheat     17009.9
# 168  Summer                Cotton(lint)     10622.0
# ...
